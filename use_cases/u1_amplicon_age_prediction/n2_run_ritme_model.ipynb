# %% [markdown]
# # Usecase 1: Age prediction run ritme models

# %% [markdown]
# The scripts launches a ritme experiments to find the best model configuration. It can be run in the following conda environment:
# ```shell
# mamba create -n ritme_model -c adamova -c qiime2 -c conda-forge -c bioconda -c pytorch -c anaconda ritme ipykernel -y
# conda activate ritme_model
# pip install -e .
# ```
#
# Note: The shell scripts are written for a high performance computer (HPC) running with Ubuntu and a slurm job manager. Feel free to adjust it to your HPC working set-up.

# %% [markdown]
# ## Calculate best model + feature engineering configuration with TPESampler

# %% [markdown]
# see scripts `n2_model_{MODEL_TYPE}_tpe.sh`

# %% [markdown]
# ## Display best regressor

# %%
import pickle

path_to_best = "/cluster/project/bokulich/adamova/ritme_usecase_runs_final_time/u1_xgb_tpe/xgb_best_model.pkl"

# read best model
with open(path_to_best, "rb") as file:
    best_model = pickle.load(file)

# extract feature engineering settings of best model
best_model.data_config
# Out:
# /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/qiime2/core/archive/provenance.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# {'data_aggregation': None,
#  'data_selection': 'abundance_topi',
#  'data_selection_i': 3906,
#  'data_transform': 'ilr',
#  'data_enrich': 'shannon_and_metadata',
#  'data_enrich_with': ['health_status_at_sampling',
#   'diet_milk',
#   'diet_weaning',
#   'abx_7d_prior'],
#  'data_alr_denom_idx': None}
