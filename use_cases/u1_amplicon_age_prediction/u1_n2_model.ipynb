# %% [markdown]
# # Usecase 1: Age prediction run model

# %% [markdown]
# The scripts displayed can be run in the following conda environment:
# ```shell
# mamba create -n ritme_model -c adamova -c qiime2 -c conda-forge -c bioconda -c pytorch -c anaconda ritme ipykernel -y
# conda activate ritme_model
# ```
#
# Note: The shell scripts were written for a high performance computer (HPC) running with Ubuntu and a slurm job manager. Feel free to adjust them to your HPC working set-up.

# %% [markdown]
# ## Calculate best model + feature engineering configuration

# %% [markdown]
# ### RandomForest models only

# %% [markdown]
# see script `u1_n2_model_rf.sh`

# %% [markdown]
# ### All model types with MLflow

# %% [markdown]
# see script `u1_n2_model_all.sh`

# %% [markdown]
# ### All model types with WandB

# %%
see script `u1_n2_model_all_wandb.sh`
