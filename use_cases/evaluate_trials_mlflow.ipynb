# %% [markdown]
# ## Setup

# %%
import warnings

import mlflow

from ritme.evaluate_mlflow import (
    barplot_metric,
    extract_run_config,
    parallel_coordinates_plot,
    plot_avg_history_per_model_type,
    plot_complexity_vs_metric,
    plot_metric_history_per_model_type,
    plot_trend_over_time,
    post_process_data_transform,
    violinplot_metric,
    boxplot_metric,
)

warnings.filterwarnings("ignore", category=FutureWarning)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
######## USER INPUTS ########

# path to MLflow logs
log_folder_location = "/cluster/work/bokulich/adamova/ritme_usecase_runs_final/u2_nnreg_tpe/mlruns"

# whether to only analyze one model type or all (="all")
model_type = "all"
# whether to display all trials (top_n=None) or just top N trials of the
# model_type selected before
top_n = None

# static or dynamic plots (static_plots=False) if available?
static_plots = True

# whether to display trial_id as x-axis in plots
display_trial_id = False
######## END USER INPUTS #####

# %% [markdown]
# ## Extract trial information

# %%
# extract all trial information
mlflow.set_tracking_uri(log_folder_location)

all_trials = mlflow.search_runs(
    order_by=["metrics.rmse_val ASC"], search_all_experiments=True
)

print(f"Found {all_trials.shape[0]} trials")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # extract all trial information
#       2 mlflow.set_tracking_uri(log_folder_location)
# ----> 4 all_trials = mlflow.search_runs(
#       5     order_by=["metrics.rmse_val ASC"], search_all_experiments=True
#       6 )
#       8 print(f"Found {all_trials.shape[0]} trials")
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/tracking/fluent.py:2893, in search_runs(experiment_ids, filter_string, run_view_type, max_results, order_by, output_format, search_all_experiments, experiment_names)
#    2883     def pagination_wrapper_func(number_to_get, next_page_token):
#    2884         return MlflowClient().search_runs(
#    2885             experiment_ids,
#    2886             filter_string,
#    (...)
#    2890             next_page_token,
#    2891         )
# -> 2893     runs = get_results_from_paginated_fn(
#    2894         pagination_wrapper_func,
#    2895         NUM_RUNS_PER_PAGE_PANDAS,
#    2896         max_results,
#    2897     )
#    2899 if output_format == "list":
#    2900     return runs  # List[mlflow.entities.run.Run]
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/utils/__init__.py:238, in get_results_from_paginated_fn(paginated_fn, max_results_per_page, max_results)
#     236     page_results = paginated_fn(num_to_get, next_page_token)
#     237 else:
# --> 238     page_results = paginated_fn(max_results_per_page, next_page_token)
#     239 all_results.extend(page_results)
#     240 if hasattr(page_results, "token") and page_results.token:
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/tracking/fluent.py:2884, in search_runs.<locals>.pagination_wrapper_func(number_to_get, next_page_token)
#    2883 def pagination_wrapper_func(number_to_get, next_page_token):
# -> 2884     return MlflowClient().search_runs(
#    2885         experiment_ids,
#    2886         filter_string,
#    2887         run_view_type,
#    2888         number_to_get,
#    2889         order_by,
#    2890         next_page_token,
#    2891     )
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/tracking/client.py:3577, in MlflowClient.search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#    3488 def search_runs(
#    3489     self,
#    3490     experiment_ids: list[str],
#    (...)
#    3495     page_token: Optional[str] = None,
#    3496 ) -> PagedList[Run]:
#    3497     """
#    3498     Search for Runs that fit the specified criteria.
#    3499
#    (...)
#    3575         tags: {'s.release': '1.1.0-RC'}
#    3576     """
# -> 3577     return self._tracking_client.search_runs(
#    3578         experiment_ids, filter_string, run_view_type, max_results, order_by, page_token
#    3579     )
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:819, in TrackingServiceClient.search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     817 if isinstance(experiment_ids, int) or is_string_type(experiment_ids):
#     818     experiment_ids = [experiment_ids]
# --> 819 return self.store.search_runs(
#     820     experiment_ids=experiment_ids,
#     821     filter_string=filter_string,
#     822     run_view_type=run_view_type,
#     823     max_results=max_results,
#     824     order_by=order_by,
#     825     page_token=page_token,
#     826 )
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/store/tracking/abstract_store.py:616, in AbstractStore.search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     587 def search_runs(
#     588     self,
#     589     experiment_ids,
#    (...)
#     594     page_token=None,
#     595 ):
#     596     """
#     597     Return runs that match the given list of search expressions within the experiments.
#     598
#    (...)
#     614         meaningful in such cases.
#     615     """
# --> 616     runs, token = self._search_runs(
#     617         experiment_ids,
#     618         filter_string,
#     619         run_view_type,
#     620         max_results,
#     621         order_by,
#     622         page_token,
#     623     )
#     624     return PagedList(runs, token)
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/store/tracking/file_store.py:1031, in FileStore._search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#    1029 for experiment_id in experiment_ids:
#    1030     run_infos = self._list_run_infos(experiment_id, run_view_type)
# -> 1031     runs.extend(self._get_run_from_info(r) for r in run_infos)
#    1032 filtered = SearchUtils.filter(runs, filter_string)
#    1033 sorted_runs = SearchUtils.sort(filtered, order_by)
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/store/tracking/file_store.py:1031, in <genexpr>(.0)
#    1029 for experiment_id in experiment_ids:
#    1030     run_infos = self._list_run_infos(experiment_id, run_view_type)
# -> 1031     runs.extend(self._get_run_from_info(r) for r in run_infos)
#    1032 filtered = SearchUtils.filter(runs, filter_string)
#    1033 sorted_runs = SearchUtils.sort(filtered, order_by)
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/store/tracking/file_store.py:750, in FileStore._get_run_from_info(self, run_info)
#     749 def _get_run_from_info(self, run_info):
# --> 750     metrics = self._get_all_metrics(run_info)
#     751     params = self._get_all_params(run_info)
#     752     tags = self._get_all_tags(run_info)
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/store/tracking/file_store.py:846, in FileStore._get_all_metrics(self, run_info)
#     843 metrics = []
#     844 for metric_file in metric_files:
#     845     metrics.append(
# --> 846         self._get_metric_from_file(
#     847             parent_path, metric_file, run_info.run_id, run_info.experiment_id
#     848         )
#     849     )
#     850 return metrics
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/store/tracking/file_store.py:826, in FileStore._get_metric_from_file(parent_path, metric_name, run_id, exp_id)
#     819 @staticmethod
#     820 def _get_metric_from_file(
#     821     parent_path: str, metric_name: str, run_id: str, exp_id: str
#     822 ) -> Metric:
#     823     _validate_metric_name(metric_name)
#     824     metric_objs = [
#     825         FileStore._get_metric_from_line(run_id, metric_name, line, exp_id)
# --> 826         for line in read_file_lines(parent_path, metric_name)
#     827     ]
#     828     if len(metric_objs) == 0:
#     829         raise ValueError(f"Metric '{metric_name}' is malformed. No data found.")
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/site-packages/mlflow/utils/file_utils.py:297, in read_file_lines(parent_path, file_name)
#     295 file_path = os.path.join(parent_path, file_name)
#     296 with codecs.open(file_path, mode="r", encoding=ENCODING) as f:
# --> 297     return f.readlines()
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/codecs.py:709, in StreamReaderWriter.readlines(self, sizehint)
#     707 def readlines(self, sizehint=None):
# --> 709     return self.reader.readlines(sizehint)
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/codecs.py:618, in StreamReader.readlines(self, sizehint, keepends)
#     606 def readlines(self, sizehint=None, keepends=True):
#     608     """ Read all lines available on the input stream
#     609         and return them as a list.
#     610
#    (...)
#     616
#     617     """
# --> 618     data = self.read()
#     619     return data.splitlines(keepends)
#
# File /cluster/project/bokulich/adamova/_conda_envs/ritme_model/lib/python3.10/codecs.py:496, in StreamReader.read(self, size, chars, firstline)
#     494 # we need more data
#     495 if size < 0:
# --> 496     newdata = self.stream.read()
#     497 else:
#     498     newdata = self.stream.read(size)
#
# KeyboardInterrupt:

# %%
# post-process data_transform entry - only needed in MLflow since WandB updates
# these automatically
all_trials = post_process_data_transform(all_trials)

# %%
if model_type != "all":
    print(f"Analyzing trials for model type: {model_type}")
    all_trials = all_trials[all_trials["params.model"] == model_type]

# select trails to analyze
if top_n is not None:
    print(f"Analyzing top {top_n} trials")
    all_trials = all_trials.head(top_n)

print(f"Selected {all_trials.shape[0]} trials")

# %% [markdown]
# ## Insights on performance per model type

# %%
boxplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col="params.model",
    group_name="Model type",
)

# %%
violinplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col="params.model",
    group_name="Model type",
)

# %%
barplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col="params.model",
    group_name="Model type",
    display_trial_name=display_trial_id,
    top_n=top_n,
)

# %% [markdown]
# ## Model complexity vs. performance

# %%
plot_complexity_vs_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col="params.model",
    group_name="Model type",
    static=static_plots,  # Set to False for interactive plotly graph
)

# %%
violinplot_metric(
    all_trials,
    metric_col="metrics.nb_features",
    metric_name="Number of features",
    group_col="params.model",
    group_name="Model type",
)

# %%
first_metric_col = "metrics.nb_features"
first_metric_name = "# features"
parallel_coordinates_plot(all_trials, first_metric_col, first_metric_name)

# %% [markdown]
# ## Performance vs. feature engineering

# %% [markdown]
# ### Effect of data transformation

# %%
var = "params.data_transform"
var_name = "Data transform"

barplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
    display_trial_name=display_trial_id,
    top_n=top_n,
)

# %%
boxplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
violinplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
parallel_coordinates_plot(all_trials, var, var_name, first_metric_cat=True)

# %% [markdown]
# ### Effect of data selection

# %%
var = "params.data_selection"
var_name = "Data selection"

barplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
    display_trial_name=display_trial_id,
    top_n=top_n,
)

# %%
boxplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
violinplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
parallel_coordinates_plot(all_trials, var, var_name, first_metric_cat=True)

# %% [markdown]
# ### Effect of data aggregation

# %%
var = "params.data_aggregation"
var_name = "Data aggregation"

barplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
    display_trial_name=display_trial_id,
    top_n=top_n,
)

# %%
boxplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
violinplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
parallel_coordinates_plot(all_trials, var, var_name, first_metric_cat=True)

# %% [markdown]
# ### Effect of data enrichment

# %%
var = "params.data_enrich"
var_name = "Data enrichment"

barplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
    display_trial_name=display_trial_id,
    top_n=top_n,
)

# %%
boxplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
violinplot_metric(
    all_trials,
    metric_col="metrics.rmse_val",
    metric_name="RMSE Validation",
    group_col=var,
    group_name=var_name,
)

# %%
parallel_coordinates_plot(all_trials, var, var_name, first_metric_cat=True)

# %% [markdown]
# ## Training over time

# %%
metric = "rmse_train"
for model in all_trials["params.model"].unique():
    print(f"Plotting trend for model: {model}")
    model_trials = all_trials[all_trials["params.model"] == model]
    plot_trend_over_time(
        model_trials, f"metrics.{metric}", window=20, title_prefix=f"Model: {model}"
    )

# %%
client = mlflow.tracking.MlflowClient(tracking_uri=log_folder_location)

# one figure per model type
for model_type in all_trials["params.model"].unique():
    model_trials = all_trials[all_trials["params.model"] == model_type]
    plot_metric_history_per_model_type(metric, client, model_trials)

# %%
# plot all metric history in one plot
plot_metric_history_per_model_type(metric, client, all_trials)

# %% [markdown]
# * If per model type later launched trials yield smaller RMSE train then the selected search algorithm works
# * *Note:* The classification network (`nn_class`) is trained by minimizing the cross‐entropy loss, and the ordinal‐regression variant (`nn_corn`) is trained by minimizing the CORN loss.  herefore, training curves based on MSE‐derived metrics (e.g. RMSE) are not guaranteed to decrease monotonically during optimization for these models.

# %%
plot_avg_history_per_model_type("rmse_train", client, all_trials)

# %%
plot_avg_history_per_model_type("rmse_val", client, all_trials)

# %% [markdown]
# ## Run configuration overview

# %%
run_config = extract_run_config(all_trials)
run_config
